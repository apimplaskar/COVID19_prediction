# %%
# Packages
import numpy as np
import sklearn 
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.integrate import odeint
import math

from utility_code.utility import utils

#import csvs
train = pd.read_csv("ucla2020-cs145-covid19-prediction/train.csv")
test = pd.read_csv("ucla2020-cs145-covid19-prediction/test.csv")
graph = pd.read_csv("ucla2020-cs145-covid19-prediction/graph.csv")
dummydata = pd.read_csv("data-test/raw_data_test.csv", skiprows=2, thousands=',')

train['Population'] = train['Confirmed'].divide(train['Incident_Rate'])*1e5
train['Active/Population'] = train['Active'].divide(train['Population'])
train['Deaths/Population'] = train['Deaths'].divide(train['Population'])
train['Active/People_Tested*Population'] = train['Active']/train['People_Tested']*train['Population']
train['Recovered/Population'] = train['Recovered']/train['Population']


confirmed = train['Confirmed'].to_list()
daily = [confirmed[i]-confirmed[i-50] for i in range(len(confirmed)) if i-50 >= 0]
for i in range(50):
    daily.insert(0,0)

train['New_Cases'] = daily

tests = train['People_Tested'].to_list()
dailyTests = [tests[i]-tests[i-50] for i in range(len(tests)) if i-50 >= 0]
for i in range(50):
    dailyTests.insert(0,0)

train['New_Tests'] = dailyTests

train['New_Cases/New_Tests'] = train['New_Cases']/train['New_Tests']

statesdata = {}
states = pd.Series.unique(train['Province_State'])
num_states = len(states)
for s in states:
    statesdata[s] = train.loc[train['Province_State'] == s ,:]

# %%
from statsmodels.tsa.arima.model import ARIMA
optparams = None
optmape = 100
for p in [2,4,6,8,10]:
    for diff in [1,2,3,4,5]:
        for q in [1,2,3,4,5]:
            confirmed = statesdata['Alabama']['Confirmed']
            confirmed = confirmed.reset_index()
            confirmed = confirmed.drop(columns=['index'])
            #print(confirmed)
            splitpt = len(confirmed) - 10
            confirmed_train, confirmed_test = confirmed[0:splitpt], confirmed[splitpt:]

            def difference(dataset, interval = 1):
                diff = list()
                for i in range(interval, len(dataset)):
                    value = dataset[i]-dataset[i-interval]
                    diff.append(value)
                return np.array(diff)

            # invert differenced value
            def inverse_difference(history, yhat, interval=1):
                #yhat = np.exp(yhat)
                return yhat + history[-1]

            series = confirmed_train
            X = series.values
            #X = np.log(series.values)
            differenced = difference(X, 1)

            model = ARIMA(X, order=(4, 2, q))
            model_fit = model.fit()
            #print(model_fit.summary())

            start = len(differenced)
            end = len(differenced)+10
            #forecast = model_fit.predict(start = start, end = end, )
            fc= model_fit.predict(start, end)

            #print(p,diff,q)
            mape = MAPE(pd.DataFrame({'Confirmed':fc}), pd.DataFrame(confirmed_test))['Confirmed']
            if mape < optmape:
                optparams = {'p':p, 'd':diff, 'q':q}
                optmape = mape
            


# for t in range(len(confirmed_test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast()
#     y = output
#     predictions.append(y)
#     #obs = confirmed_test[t]
# Out:
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
print('Params:', optparams)
print('MAPE:', optmape)
# Out:
# Params: {'p': 2, 'd': 1, 'q': 3}
# MAPE: 0.002708442240741531

# %%
start = len(differenced)
end = len(differenced)+10
#forecast = model_fit.predict(start = start, end = end, )
fc= model_fit.predict(start, end)

# %%
MAPE(pd.DataFrame({'Confirmed':fc}), pd.DataFrame(confirmed_test))
# Out:
# index        0.879510
# Confirmed    0.008076
# dtype: float64

# %%
history = [x for x in X]
#print(history[-1])
day = 1
for yhat in forecast:
    inverted = inverse_difference(history, yhat, 1)
    print('Day', day,':', inverted)
    history.append(inverted)
    day+=1
# Out:
# Day 1 : [114722.01526319]
# Day 2 : [115653.72950221]
# Day 3 : [116678.61223306]
# Day 4 : [117760.12147352]
# Day 5 : [118791.29901588]
# Day 6 : [119836.44718097]
# Day 7 : [120895.14942917]
# Day 8 : [121916.96869413]
# Day 9 : [122929.20828124]
# Day 10 : [123960.35445294]
# Day 11 : [124990.1773984]

# %%
confirmed_test
# Out:
#      Confirmed
# 132     114532
# 133     115060
# 134     116710
# 135     117242
# 136     119254
# 137     121023
# 138     122185
# 139     123889
# 140     125235
# 141     126058

# %%
def difference(dataset, interval = 1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i]-dataset[i-interval]
        diff.append(value)
    return np.array(diff)
differenced = difference(difference(X), 1)
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(differenced)

# %%
differenced = difference(X, 1)
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(differenced)

# %%
def difference(dataset, interval = 1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i]-dataset[i-interval]
        diff.append(value)
    return np.array(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
    #yhat = np.exp(yhat)
    return yhat + history[-1]


days = 26
from statsmodels.tsa.arima.model import ARIMA
#from statsmodels.tsa.arima.model import s

proj = {}
for s in states:
    a = statesdata[s]
    a = a.reset_index()
    confirmed = a['Confirmed']
    deaths = a['Deaths']
    
    X = confirmed.values
    differencedC = difference(X, 2)

    #modelC = 
    modelC = ARIMA(X, order=(5,2,3))
    model_fitC = modelC.fit()
    start = len(X)
    forecastC = model_fitC.predict(start = start, end = start + days)
#     print(model_fit.summary())
    
#     predictionC = []
#     history = [x for x in X]
#     #print(history[-1])
#     day = 1
#     for yhat in forecastC:
#         inverted = inverse_difference(history, yhat, 1)
#         predictionC.append(inverted)
# #         print('Day', day,':', math.exp(inverted))
#         history.append(inverted)
#         day+=1
        
    Y= deaths.values
    differencedD = difference(Y, 2)

    modelD = ARIMA(Y, order=(5,2,3))
    model_fitD = modelD.fit()
    start = len(Y)
    forecastD = model_fitD.predict(start = start, end = start + days)
#     print(model_fit.summary())
    
#     predictionD = []
#     history = [y for y in Y]
#     #print(history[-1])
#     day = 1
#     for yhat in forecastD:
#         inverted = inverse_difference(history, yhat, 1)
#         predictionD.append(inverted)
# #         print('Day', day,':', math.exp(inverted))
#         history.append(inverted)
#         day+=1
    
    df = {'Confirmed': forecastC, 'Deaths': forecastD}
    
    proj[s] = pd.DataFrame(df)
    
# for t in range(len(confirmed_test)):
#     model = ARIMA(history, order=(5,1,0))
#     model_fit = model.fit()
#     output = model_fit.forecast()
#     y = output
#     predictions.append(y)
#     #obs = confirmed_test[t]
# Out:
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/Aditya/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)

# %%
order = test.loc[0:49,'Province_State']
test

# format submission
conf = []
dead = []
fid = 0
for i in range(days):
    for j in order:
        projection = proj[j].iloc[i]
        print(j, 'day', i)
        conf.append(int(projection['Confirmed']))
        dead.append(int(projection['Deaths']))
        print(fid)
        fid+=1
# Out:
# Alabama day 0
# 0
# Alaska day 0
# 1
# Arizona day 0
# 2
# Arkansas day 0
# 3
# California day 0
# 4
# Colorado day 0
# 5
# Connecticut day 0
# 6
# Delaware day 0
# 7
# Florida day 0
# 8
# Georgia day 0
# 9
# Hawaii day 0
# 10
# Idaho day 0
# 11
# Illinois day 0
# 12
# Indiana day 0
# 13
# Iowa day 0
# 14
# Kansas day 0
# 15
# Kentucky day 0
# 16
# Louisiana day 0
# 17
# Maine day 0
# 18
# Maryland day 0
# 19
# Massachusetts day 0
# 20
# Michigan day 0
# 21
# Minnesota day 0
# 22
# Mississippi day 0
# 23
# Missouri day 0
# 24
# Montana day 0
# 25
# Nebraska day 0
# 26
# Nevada day 0
# 27
# New Hampshire day 0
# 28
# New Jersey day 0
# 29
# New Mexico day 0
# 30
# New York day 0
# 31
# North Carolina day 0
# 32
# North Dakota day 0
# 33
# Ohio day 0
# 34
# Oklahoma day 0
# 35
# Oregon day 0
# 36
# Pennsylvania day 0
# 37
# Rhode Island day 0
# 38
# South Carolina day 0
# 39
# South Dakota day 0
# 40
# Tennessee day 0
# 41
# Texas day 0
# 42
# Utah day 0
# 43
# Vermont day 0
# 44
# Virginia day 0
# 45
# Washington day 0
# 46
# West Virginia day 0
# 47
# Wisconsin day 0
# 48
# Wyoming day 0
# 49
# Alabama day 1
# 50
# Alaska day 1
# 51
# Arizona day 1
# 52
# Arkansas day 1
# 53
# California day 1
# 54
# Colorado day 1
# 55
# Connecticut day 1
# 56
# Delaware day 1
# 57
# Florida day 1
# 58
# Georgia day 1
# 59
# Hawaii day 1
# 60
# Idaho day 1
# 61
# Illinois day 1
# 62
# Indiana day 1
# 63
# Iowa day 1
# 64
# Kansas day 1
# 65
# Kentucky day 1
# 66
# Louisiana day 1
# 67
# Maine day 1
# 68
# Maryland day 1
# 69
# Massachusetts day 1
# 70
# Michigan day 1
# 71
# Minnesota day 1
# 72
# Mississippi day 1
# 73
# Missouri day 1
# 74
# Montana day 1
# 75
# Nebraska day 1
# 76
# Nevada day 1
# 77
# New Hampshire day 1
# 78
# New Jersey day 1
# 79
# New Mexico day 1
# 80
# New York day 1
# 81
# North Carolina day 1
# 82
# North Dakota day 1
# 83
# Ohio day 1
# 84
# Oklahoma day 1
# 85
# Oregon day 1
# 86
# Pennsylvania day 1
# 87
# Rhode Island day 1
# 88
# South Carolina day 1
# 89
# South Dakota day 1
# 90
# Tennessee day 1
# 91
# Texas day 1
# 92
# Utah day 1
# 93
# Vermont day 1
# 94
# Virginia day 1
# 95
# Washington day 1
# 96
# West Virginia day 1
# 97
# Wisconsin day 1
# 98
# Wyoming day 1
# 99
# Alabama day 2
# 100
# Alaska day 2
# 101
# Arizona day 2
# 102
# Arkansas day 2
# 103
# California day 2
# 104
# Colorado day 2
# 105
# Connecticut day 2
# 106
# Delaware day 2
# 107
# Florida day 2
# 108
# Georgia day 2
# 109
# Hawaii day 2
# 110
# Idaho day 2
# 111
# Illinois day 2
# 112
# Indiana day 2
# 113
# Iowa day 2
# 114
# Kansas day 2
# 115
# Kentucky day 2
# 116
# Louisiana day 2
# 117
# Maine day 2
# 118
# Maryland day 2
# 119
# Massachusetts day 2
# 120
# Michigan day 2
# 121
# Minnesota day 2
# 122
# Mississippi day 2
# 123
# Missouri day 2
# 124
# Montana day 2
# 125
# Nebraska day 2
# 126
# Nevada day 2
# 127
# New Hampshire day 2
# 128
# New Jersey day 2
# 129
# New Mexico day 2
# 130
# New York day 2
# 131
# North Carolina day 2
# 132
# North Dakota day 2
# 133
# Ohio day 2
# 134
# Oklahoma day 2
# 135
# Oregon day 2
# 136
# Pennsylvania day 2
# 137
# Rhode Island day 2
# 138
# South Carolina day 2
# 139
# South Dakota day 2
# 140
# Tennessee day 2
# 141
# Texas day 2
# 142
# Utah day 2
# 143
# Vermont day 2
# 144
# Virginia day 2
# 145
# Washington day 2
# 146
# West Virginia day 2
# 147
# Wisconsin day 2
# 148
# Wyoming day 2
# 149
# Alabama day 3
# 150
# Alaska day 3
# 151
# Arizona day 3
# 152
# Arkansas day 3
# 153
# California day 3
# 154
# Colorado day 3
# 155
# Connecticut day 3
# 156
# Delaware day 3
# 157
# Florida day 3
# 158
# Georgia day 3
# 159
# Hawaii day 3
# 160
# Idaho day 3
# 161
# Illinois day 3
# 162
# Indiana day 3
# 163
# Iowa day 3
# 164
# Kansas day 3
# 165
# Kentucky day 3
# 166
# Louisiana day 3
# 167
# Maine day 3
# 168
# Maryland day 3
# 169
# Massachusetts day 3
# 170
# Michigan day 3
# 171
# Minnesota day 3
# 172
# Mississippi day 3
# 173
# Missouri day 3
# 174
# Montana day 3
# 175
# Nebraska day 3
# 176
# Nevada day 3
# 177
# New Hampshire day 3
# 178
# New Jersey day 3
# 179
# New Mexico day 3
# 180
# New York day 3
# 181
# North Carolina day 3
# 182
# North Dakota day 3
# 183
# Ohio day 3
# 184
# Oklahoma day 3
# 185
# Oregon day 3
# 186
# Pennsylvania day 3
# 187
# Rhode Island day 3
# 188
# South Carolina day 3
# 189
# South Dakota day 3
# 190
# Tennessee day 3
# 191
# Texas day 3
# 192
# Utah day 3
# 193
# Vermont day 3
# 194
# Virginia day 3
# 195
# Washington day 3
# 196
# West Virginia day 3
# 197
# Wisconsin day 3
# 198
# Wyoming day 3
# 199
# Alabama day 4
# 200
# Alaska day 4
# 201
# Arizona day 4
# 202
# Arkansas day 4
# 203
# California day 4
# 204
# Colorado day 4
# 205
# Connecticut day 4
# 206
# Delaware day 4
# 207
# Florida day 4
# 208
# Georgia day 4
# 209
# Hawaii day 4
# 210
# Idaho day 4
# 211
# Illinois day 4
# 212
# Indiana day 4
# 213
# Iowa day 4
# 214
# Kansas day 4
# 215
# Kentucky day 4
# 216
# Louisiana day 4
# 217
# Maine day 4
# 218
# Maryland day 4
# 219
# Massachusetts day 4
# 220
# Michigan day 4
# 221
# Minnesota day 4
# 222
# Mississippi day 4
# 223
# Missouri day 4
# 224
# Montana day 4
# 225
# Nebraska day 4
# 226
# Nevada day 4
# 227
# New Hampshire day 4
# 228
# New Jersey day 4
# 229
# New Mexico day 4
# 230
# New York day 4
# 231
# North Carolina day 4
# 232
# North Dakota day 4
# 233
# Ohio day 4
# 234
# Oklahoma day 4
# 235
# Oregon day 4
# 236
# Pennsylvania day 4
# 237
# Rhode Island day 4
# 238
# South Carolina day 4
# 239
# South Dakota day 4
# 240
# Tennessee day 4
# 241
# Texas day 4
# 242
# Utah day 4
# 243
# Vermont day 4
# 244
# Virginia day 4
# 245
# Washington day 4
# 246
# West Virginia day 4
# 247
# Wisconsin day 4
# 248
# Wyoming day 4
# 249
# Alabama day 5
# 250
# Alaska day 5
# 251
# Arizona day 5
# 252
# Arkansas day 5
# 253
# California day 5
# 254
# Colorado day 5
# 255
# Connecticut day 5
# 256
# Delaware day 5
# 257
# Florida day 5
# 258
# Georgia day 5
# 259
# Hawaii day 5
# 260
# Idaho day 5
# 261
# Illinois day 5
# 262
# Indiana day 5
# 263
# Iowa day 5
# 264
# Kansas day 5
# 265
# Kentucky day 5
# 266
# Louisiana day 5
# 267
# Maine day 5
# 268
# Maryland day 5
# 269
# Massachusetts day 5
# 270
# Michigan day 5
# 271
# Minnesota day 5
# 272
# Mississippi day 5
# 273
# Missouri day 5
# 274
# Montana day 5
# 275
# Nebraska day 5
# 276
# Nevada day 5
# 277
# New Hampshire day 5
# 278
# New Jersey day 5
# 279
# New Mexico day 5
# 280
# New York day 5
# 281
# North Carolina day 5
# 282
# North Dakota day 5
# 283
# Ohio day 5
# 284
# Oklahoma day 5
# 285
# Oregon day 5
# 286
# Pennsylvania day 5
# 287
# Rhode Island day 5
# 288
# South Carolina day 5
# 289
# South Dakota day 5
# 290
# Tennessee day 5
# 291
# Texas day 5
# 292
# Utah day 5
# 293
# Vermont day 5
# 294
# Virginia day 5
# 295
# Washington day 5
# 296
# West Virginia day 5
# 297
# Wisconsin day 5
# 298
# Wyoming day 5
# 299
# Alabama day 6
# 300
# Alaska day 6
# 301
# Arizona day 6
# 302
# Arkansas day 6
# 303
# California day 6
# 304
# Colorado day 6
# 305
# Connecticut day 6
# 306
# Delaware day 6
# 307
# Florida day 6
# 308
# Georgia day 6
# 309
# Hawaii day 6
# 310
# Idaho day 6
# 311
# Illinois day 6
# 312
# Indiana day 6
# 313
# Iowa day 6
# 314
# Kansas day 6
# 315
# Kentucky day 6
# 316
# Louisiana day 6
# 317
# Maine day 6
# 318
# Maryland day 6
# 319
# Massachusetts day 6
# 320
# Michigan day 6
# 321
# Minnesota day 6
# 322
# Mississippi day 6
# 323
# Missouri day 6
# 324
# Montana day 6
# 325
# Nebraska day 6
# 326
# Nevada day 6
# 327
# New Hampshire day 6
# 328
# New Jersey day 6
# 329
# New Mexico day 6
# 330
# New York day 6
# 331
# North Carolina day 6
# 332
# North Dakota day 6
# 333
# Ohio day 6
# 334
# Oklahoma day 6
# 335
# Oregon day 6
# 336
# Pennsylvania day 6
# 337
# Rhode Island day 6
# 338
# South Carolina day 6
# 339
# South Dakota day 6
# 340
# Tennessee day 6
# 341
# Texas day 6
# 342
# Utah day 6
# 343
# Vermont day 6
# 344
# Virginia day 6
# 345
# Washington day 6
# 346
# West Virginia day 6
# 347
# Wisconsin day 6
# 348
# Wyoming day 6
# 349
# Alabama day 7
# 350
# Alaska day 7
# 351
# Arizona day 7
# 352
# Arkansas day 7
# 353
# California day 7
# 354
# Colorado day 7
# 355
# Connecticut day 7
# 356
# Delaware day 7
# 357
# Florida day 7
# 358
# Georgia day 7
# 359
# Hawaii day 7
# 360
# Idaho day 7
# 361
# Illinois day 7
# 362
# Indiana day 7
# 363
# Iowa day 7
# 364
# Kansas day 7
# 365
# Kentucky day 7
# 366
# Louisiana day 7
# 367
# Maine day 7
# 368
# Maryland day 7
# 369
# Massachusetts day 7
# 370
# Michigan day 7
# 371
# Minnesota day 7
# 372
# Mississippi day 7
# 373
# Missouri day 7
# 374
# Montana day 7
# 375
# Nebraska day 7
# 376
# Nevada day 7
# 377
# New Hampshire day 7
# 378
# New Jersey day 7
# 379
# New Mexico day 7
# 380
# New York day 7
# 381
# North Carolina day 7
# 382
# North Dakota day 7
# 383
# Ohio day 7
# 384
# Oklahoma day 7
# 385
# Oregon day 7
# 386
# Pennsylvania day 7
# 387
# Rhode Island day 7
# 388
# South Carolina day 7
# 389
# South Dakota day 7
# 390
# Tennessee day 7
# 391
# Texas day 7
# 392
# Utah day 7
# 393
# Vermont day 7
# 394
# Virginia day 7
# 395
# Washington day 7
# 396
# West Virginia day 7
# 397
# Wisconsin day 7
# 398
# Wyoming day 7
# 399
# Alabama day 8
# 400
# Alaska day 8
# 401
# Arizona day 8
# 402
# Arkansas day 8
# 403
# California day 8
# 404
# Colorado day 8
# 405
# Connecticut day 8
# 406
# Delaware day 8
# 407
# Florida day 8
# 408
# Georgia day 8
# 409
# Hawaii day 8
# 410
# Idaho day 8
# 411
# Illinois day 8
# 412
# Indiana day 8
# 413
# Iowa day 8
# 414
# Kansas day 8
# 415
# Kentucky day 8
# 416
# Louisiana day 8
# 417
# Maine day 8
# 418
# Maryland day 8
# 419
# Massachusetts day 8
# 420
# Michigan day 8
# 421
# Minnesota day 8
# 422
# Mississippi day 8
# 423
# Missouri day 8
# 424
# Montana day 8
# 425
# Nebraska day 8
# 426
# Nevada day 8
# 427
# New Hampshire day 8
# 428
# New Jersey day 8
# 429
# New Mexico day 8
# 430
# New York day 8
# 431
# North Carolina day 8
# 432
# North Dakota day 8
# 433
# Ohio day 8
# 434
# Oklahoma day 8
# 435
# Oregon day 8
# 436
# Pennsylvania day 8
# 437
# Rhode Island day 8
# 438
# South Carolina day 8
# 439
# South Dakota day 8
# 440
# Tennessee day 8
# 441
# Texas day 8
# 442
# Utah day 8
# 443
# Vermont day 8
# 444
# Virginia day 8
# 445
# Washington day 8
# 446
# West Virginia day 8
# 447
# Wisconsin day 8
# 448
# Wyoming day 8
# 449
# Alabama day 9
# 450
# Alaska day 9
# 451
# Arizona day 9
# 452
# Arkansas day 9
# 453
# California day 9
# 454
# Colorado day 9
# 455
# Connecticut day 9
# 456
# Delaware day 9
# 457
# Florida day 9
# 458
# Georgia day 9
# 459
# Hawaii day 9
# 460
# Idaho day 9
# 461
# Illinois day 9
# 462
# Indiana day 9
# 463
# Iowa day 9
# 464
# Kansas day 9
# 465
# Kentucky day 9
# 466
# Louisiana day 9
# 467
# Maine day 9
# 468
# Maryland day 9
# 469
# Massachusetts day 9
# 470
# Michigan day 9
# 471
# Minnesota day 9
# 472
# Mississippi day 9
# 473
# Missouri day 9
# 474
# Montana day 9
# 475
# Nebraska day 9
# 476
# Nevada day 9
# 477
# New Hampshire day 9
# 478
# New Jersey day 9
# 479
# New Mexico day 9
# 480
# New York day 9
# 481
# North Carolina day 9
# 482
# North Dakota day 9
# 483
# Ohio day 9
# 484
# Oklahoma day 9
# 485
# Oregon day 9
# 486
# Pennsylvania day 9
# 487
# Rhode Island day 9
# 488
# South Carolina day 9
# 489
# South Dakota day 9
# 490
# Tennessee day 9
# 491
# Texas day 9
# 492
# Utah day 9
# 493
# Vermont day 9
# 494
# Virginia day 9
# 495
# Washington day 9
# 496
# West Virginia day 9
# 497
# Wisconsin day 9
# 498
# Wyoming day 9
# 499
# Alabama day 10
# 500
# Alaska day 10
# 501
# Arizona day 10
# 502
# Arkansas day 10
# 503
# California day 10
# 504
# Colorado day 10
# 505
# Connecticut day 10
# 506
# Delaware day 10
# 507
# Florida day 10
# 508
# Georgia day 10
# 509
# Hawaii day 10
# 510
# Idaho day 10
# 511
# Illinois day 10
# 512
# Indiana day 10
# 513
# Iowa day 10
# 514
# Kansas day 10
# 515
# Kentucky day 10
# 516
# Louisiana day 10
# 517
# Maine day 10
# 518
# Maryland day 10
# 519
# Massachusetts day 10
# 520
# Michigan day 10
# 521
# Minnesota day 10
# 522
# Mississippi day 10
# 523
# Missouri day 10
# 524
# Montana day 10
# 525
# Nebraska day 10
# 526
# Nevada day 10
# 527
# New Hampshire day 10
# 528
# New Jersey day 10
# 529
# New Mexico day 10
# 530
# New York day 10
# 531
# North Carolina day 10
# 532
# North Dakota day 10
# 533
# Ohio day 10
# 534
# Oklahoma day 10
# 535
# Oregon day 10
# 536
# Pennsylvania day 10
# 537
# Rhode Island day 10
# 538
# South Carolina day 10
# 539
# South Dakota day 10
# 540
# Tennessee day 10
# 541
# Texas day 10
# 542
# Utah day 10
# 543
# Vermont day 10
# 544
# Virginia day 10
# 545
# Washington day 10
# 546
# West Virginia day 10
# 547
# Wisconsin day 10
# 548
# Wyoming day 10
# 549
# Alabama day 11
# 550
# Alaska day 11
# 551
# Arizona day 11
# 552
# Arkansas day 11
# 553
# California day 11
# 554
# Colorado day 11
# 555
# Connecticut day 11
# 556
# Delaware day 11
# 557
# Florida day 11
# 558
# Georgia day 11
# 559
# Hawaii day 11
# 560
# Idaho day 11
# 561
# Illinois day 11
# 562
# Indiana day 11
# 563
# Iowa day 11
# 564
# Kansas day 11
# 565
# Kentucky day 11
# 566
# Louisiana day 11
# 567
# Maine day 11
# 568
# Maryland day 11
# 569
# Massachusetts day 11
# 570
# Michigan day 11
# 571
# Minnesota day 11
# 572
# Mississippi day 11
# 573
# Missouri day 11
# 574
# Montana day 11
# 575
# Nebraska day 11
# 576
# Nevada day 11
# 577
# New Hampshire day 11
# 578
# New Jersey day 11
# 579
# New Mexico day 11
# 580
# New York day 11
# 581
# North Carolina day 11
# 582
# North Dakota day 11
# 583
# Ohio day 11
# 584
# Oklahoma day 11
# 585
# Oregon day 11
# 586
# Pennsylvania day 11
# 587
# Rhode Island day 11
# 588
# South Carolina day 11
# 589
# South Dakota day 11
# 590
# Tennessee day 11
# 591
# Texas day 11
# 592
# Utah day 11
# 593
# Vermont day 11
# 594
# Virginia day 11
# 595
# Washington day 11
# 596
# West Virginia day 11
# 597
# Wisconsin day 11
# 598
# Wyoming day 11
# 599
# Alabama day 12
# 600
# Alaska day 12
# 601
# Arizona day 12
# 602
# Arkansas day 12
# 603
# California day 12
# 604
# Colorado day 12
# 605
# Connecticut day 12
# 606
# Delaware day 12
# 607
# Florida day 12
# 608
# Georgia day 12
# 609
# Hawaii day 12
# 610
# Idaho day 12
# 611
# Illinois day 12
# 612
# Indiana day 12
# 613
# Iowa day 12
# 614
# Kansas day 12
# 615
# Kentucky day 12
# 616
# Louisiana day 12
# 617
# Maine day 12
# 618
# Maryland day 12
# 619
# Massachusetts day 12
# 620
# Michigan day 12
# 621
# Minnesota day 12
# 622
# Mississippi day 12
# 623
# Missouri day 12
# 624
# Montana day 12
# 625
# Nebraska day 12
# 626
# Nevada day 12
# 627
# New Hampshire day 12
# 628
# New Jersey day 12
# 629
# New Mexico day 12
# 630
# New York day 12
# 631
# North Carolina day 12
# 632
# North Dakota day 12
# 633
# Ohio day 12
# 634
# Oklahoma day 12
# 635
# Oregon day 12
# 636
# Pennsylvania day 12
# 637
# Rhode Island day 12
# 638
# South Carolina day 12
# 639
# South Dakota day 12
# 640
# Tennessee day 12
# 641
# Texas day 12
# 642
# Utah day 12
# 643
# Vermont day 12
# 644
# Virginia day 12
# 645
# Washington day 12
# 646
# West Virginia day 12
# 647
# Wisconsin day 12
# 648
# Wyoming day 12
# 649
# Alabama day 13
# 650
# Alaska day 13
# 651
# Arizona day 13
# 652
# Arkansas day 13
# 653
# California day 13
# 654
# Colorado day 13
# 655
# Connecticut day 13
# 656
# Delaware day 13
# 657
# Florida day 13
# 658
# Georgia day 13
# 659
# Hawaii day 13
# 660
# Idaho day 13
# 661
# Illinois day 13
# 662
# Indiana day 13
# 663
# Iowa day 13
# 664
# Kansas day 13
# 665
# Kentucky day 13
# 666
# Louisiana day 13
# 667
# Maine day 13
# 668
# Maryland day 13
# 669
# Massachusetts day 13
# 670
# Michigan day 13
# 671
# Minnesota day 13
# 672
# Mississippi day 13
# 673
# Missouri day 13
# 674
# Montana day 13
# 675
# Nebraska day 13
# 676
# Nevada day 13
# 677
# New Hampshire day 13
# 678
# New Jersey day 13
# 679
# New Mexico day 13
# 680
# New York day 13
# 681
# North Carolina day 13
# 682
# North Dakota day 13
# 683
# Ohio day 13
# 684
# Oklahoma day 13
# 685
# Oregon day 13
# 686
# Pennsylvania day 13
# 687
# Rhode Island day 13
# 688
# South Carolina day 13
# 689
# South Dakota day 13
# 690
# Tennessee day 13
# 691
# Texas day 13
# 692
# Utah day 13
# 693
# Vermont day 13
# 694
# Virginia day 13
# 695
# Washington day 13
# 696
# West Virginia day 13
# 697
# Wisconsin day 13
# 698
# Wyoming day 13
# 699
# Alabama day 14
# 700
# Alaska day 14
# 701
# Arizona day 14
# 702
# Arkansas day 14
# 703
# California day 14
# 704
# Colorado day 14
# 705
# Connecticut day 14
# 706
# Delaware day 14
# 707
# Florida day 14
# 708
# Georgia day 14
# 709
# Hawaii day 14
# 710
# Idaho day 14
# 711
# Illinois day 14
# 712
# Indiana day 14
# 713
# Iowa day 14
# 714
# Kansas day 14
# 715
# Kentucky day 14
# 716
# Louisiana day 14
# 717
# Maine day 14
# 718
# Maryland day 14
# 719
# Massachusetts day 14
# 720
# Michigan day 14
# 721
# Minnesota day 14
# 722
# Mississippi day 14
# 723
# Missouri day 14
# 724
# Montana day 14
# 725
# Nebraska day 14
# 726
# Nevada day 14
# 727
# New Hampshire day 14
# 728
# New Jersey day 14
# 729
# New Mexico day 14
# 730
# New York day 14
# 731
# North Carolina day 14
# 732
# North Dakota day 14
# 733
# Ohio day 14
# 734
# Oklahoma day 14
# 735
# Oregon day 14
# 736
# Pennsylvania day 14
# 737
# Rhode Island day 14
# 738
# South Carolina day 14
# 739
# South Dakota day 14
# 740
# Tennessee day 14
# 741
# Texas day 14
# 742
# Utah day 14
# 743
# Vermont day 14
# 744
# Virginia day 14
# 745
# Washington day 14
# 746
# West Virginia day 14
# 747
# Wisconsin day 14
# 748
# Wyoming day 14
# 749
# Alabama day 15
# 750
# Alaska day 15
# 751
# Arizona day 15
# 752
# Arkansas day 15
# 753
# California day 15
# 754
# Colorado day 15
# 755
# Connecticut day 15
# 756
# Delaware day 15
# 757
# Florida day 15
# 758
# Georgia day 15
# 759
# Hawaii day 15
# 760
# Idaho day 15
# 761
# Illinois day 15
# 762
# Indiana day 15
# 763
# Iowa day 15
# 764
# Kansas day 15
# 765
# Kentucky day 15
# 766
# Louisiana day 15
# 767
# Maine day 15
# 768
# Maryland day 15
# 769
# Massachusetts day 15
# 770
# Michigan day 15
# 771
# Minnesota day 15
# 772
# Mississippi day 15
# 773
# Missouri day 15
# 774
# Montana day 15
# 775
# Nebraska day 15
# 776
# Nevada day 15
# 777
# New Hampshire day 15
# 778
# New Jersey day 15
# 779
# New Mexico day 15
# 780
# New York day 15
# 781
# North Carolina day 15
# 782
# North Dakota day 15
# 783
# Ohio day 15
# 784
# Oklahoma day 15
# 785
# Oregon day 15
# 786
# Pennsylvania day 15
# 787
# Rhode Island day 15
# 788
# South Carolina day 15
# 789
# South Dakota day 15
# 790
# Tennessee day 15
# 791
# Texas day 15
# 792
# Utah day 15
# 793
# Vermont day 15
# 794
# Virginia day 15
# 795
# Washington day 15
# 796
# West Virginia day 15
# 797
# Wisconsin day 15
# 798
# Wyoming day 15
# 799
# Alabama day 16
# 800
# Alaska day 16
# 801
# Arizona day 16
# 802
# Arkansas day 16
# 803
# California day 16
# 804
# Colorado day 16
# 805
# Connecticut day 16
# 806
# Delaware day 16
# 807
# Florida day 16
# 808
# Georgia day 16
# 809
# Hawaii day 16
# 810
# Idaho day 16
# 811
# Illinois day 16
# 812
# Indiana day 16
# 813
# Iowa day 16
# 814
# Kansas day 16
# 815
# Kentucky day 16
# 816
# Louisiana day 16
# 817
# Maine day 16
# 818
# Maryland day 16
# 819
# Massachusetts day 16
# 820
# Michigan day 16
# 821
# Minnesota day 16
# 822
# Mississippi day 16
# 823
# Missouri day 16
# 824
# Montana day 16
# 825
# Nebraska day 16
# 826
# Nevada day 16
# 827
# New Hampshire day 16
# 828
# New Jersey day 16
# 829
# New Mexico day 16
# 830
# New York day 16
# 831
# North Carolina day 16
# 832
# North Dakota day 16
# 833
# Ohio day 16
# 834
# Oklahoma day 16
# 835
# Oregon day 16
# 836
# Pennsylvania day 16
# 837
# Rhode Island day 16
# 838
# South Carolina day 16
# 839
# South Dakota day 16
# 840
# Tennessee day 16
# 841
# Texas day 16
# 842
# Utah day 16
# 843
# Vermont day 16
# 844
# Virginia day 16
# 845
# Washington day 16
# 846
# West Virginia day 16
# 847
# Wisconsin day 16
# 848
# Wyoming day 16
# 849
# Alabama day 17
# 850
# Alaska day 17
# 851
# Arizona day 17
# 852
# Arkansas day 17
# 853
# California day 17
# 854
# Colorado day 17
# 855
# Connecticut day 17
# 856
# Delaware day 17
# 857
# Florida day 17
# 858
# Georgia day 17
# 859
# Hawaii day 17
# 860
# Idaho day 17
# 861
# Illinois day 17
# 862
# Indiana day 17
# 863
# Iowa day 17
# 864
# Kansas day 17
# 865
# Kentucky day 17
# 866
# Louisiana day 17
# 867
# Maine day 17
# 868
# Maryland day 17
# 869
# Massachusetts day 17
# 870
# Michigan day 17
# 871
# Minnesota day 17
# 872
# Mississippi day 17
# 873
# Missouri day 17
# 874
# Montana day 17
# 875
# Nebraska day 17
# 876
# Nevada day 17
# 877
# New Hampshire day 17
# 878
# New Jersey day 17
# 879
# New Mexico day 17
# 880
# New York day 17
# 881
# North Carolina day 17
# 882
# North Dakota day 17
# 883
# Ohio day 17
# 884
# Oklahoma day 17
# 885
# Oregon day 17
# 886
# Pennsylvania day 17
# 887
# Rhode Island day 17
# 888
# South Carolina day 17
# 889
# South Dakota day 17
# 890
# Tennessee day 17
# 891
# Texas day 17
# 892
# Utah day 17
# 893
# Vermont day 17
# 894
# Virginia day 17
# 895
# Washington day 17
# 896
# West Virginia day 17
# 897
# Wisconsin day 17
# 898
# Wyoming day 17
# 899
# Alabama day 18
# 900
# Alaska day 18
# 901
# Arizona day 18
# 902
# Arkansas day 18
# 903
# California day 18
# 904
# Colorado day 18
# 905
# Connecticut day 18
# 906
# Delaware day 18
# 907
# Florida day 18
# 908
# Georgia day 18
# 909
# Hawaii day 18
# 910
# Idaho day 18
# 911
# Illinois day 18
# 912
# Indiana day 18
# 913
# Iowa day 18
# 914
# Kansas day 18
# 915
# Kentucky day 18
# 916
# Louisiana day 18
# 917
# Maine day 18
# 918
# Maryland day 18
# 919
# Massachusetts day 18
# 920
# Michigan day 18
# 921
# Minnesota day 18
# 922
# Mississippi day 18
# 923
# Missouri day 18
# 924
# Montana day 18
# 925
# Nebraska day 18
# 926
# Nevada day 18
# 927
# New Hampshire day 18
# 928
# New Jersey day 18
# 929
# New Mexico day 18
# 930
# New York day 18
# 931
# North Carolina day 18
# 932
# North Dakota day 18
# 933
# Ohio day 18
# 934
# Oklahoma day 18
# 935
# Oregon day 18
# 936
# Pennsylvania day 18
# 937
# Rhode Island day 18
# 938
# South Carolina day 18
# 939
# South Dakota day 18
# 940
# Tennessee day 18
# 941
# Texas day 18
# 942
# Utah day 18
# 943
# Vermont day 18
# 944
# Virginia day 18
# 945
# Washington day 18
# 946
# West Virginia day 18
# 947
# Wisconsin day 18
# 948
# Wyoming day 18
# 949
# Alabama day 19
# 950
# Alaska day 19
# 951
# Arizona day 19
# 952
# Arkansas day 19
# 953
# California day 19
# 954
# Colorado day 19
# 955
# Connecticut day 19
# 956
# Delaware day 19
# 957
# Florida day 19
# 958
# Georgia day 19
# 959
# Hawaii day 19
# 960
# Idaho day 19
# 961
# Illinois day 19
# 962
# Indiana day 19
# 963
# Iowa day 19
# 964
# Kansas day 19
# 965
# Kentucky day 19
# 966
# Louisiana day 19
# 967
# Maine day 19
# 968
# Maryland day 19
# 969
# Massachusetts day 19
# 970
# Michigan day 19
# 971
# Minnesota day 19
# 972
# Mississippi day 19
# 973
# Missouri day 19
# 974
# Montana day 19
# 975
# Nebraska day 19
# 976
# Nevada day 19
# 977
# New Hampshire day 19
# 978
# New Jersey day 19
# 979
# New Mexico day 19
# 980
# New York day 19
# 981
# North Carolina day 19
# 982
# North Dakota day 19
# 983
# Ohio day 19
# 984
# Oklahoma day 19
# 985
# Oregon day 19
# 986
# Pennsylvania day 19
# 987
# Rhode Island day 19
# 988
# South Carolina day 19
# 989
# South Dakota day 19
# 990
# Tennessee day 19
# 991
# Texas day 19
# 992
# Utah day 19
# 993
# Vermont day 19
# 994
# Virginia day 19
# 995
# Washington day 19
# 996
# West Virginia day 19
# 997
# Wisconsin day 19
# 998
# Wyoming day 19
# 999
# Alabama day 20
# 1000
# Alaska day 20
# 1001
# Arizona day 20
# 1002
# Arkansas day 20
# 1003
# California day 20
# 1004
# Colorado day 20
# 1005
# Connecticut day 20
# 1006
# Delaware day 20
# 1007
# Florida day 20
# 1008
# Georgia day 20
# 1009
# Hawaii day 20
# 1010
# Idaho day 20
# 1011
# Illinois day 20
# 1012
# Indiana day 20
# 1013
# Iowa day 20
# 1014
# Kansas day 20
# 1015
# Kentucky day 20
# 1016
# Louisiana day 20
# 1017
# Maine day 20
# 1018
# Maryland day 20
# 1019
# Massachusetts day 20
# 1020
# Michigan day 20
# 1021
# Minnesota day 20
# 1022
# Mississippi day 20
# 1023
# Missouri day 20
# 1024
# Montana day 20
# 1025
# Nebraska day 20
# 1026
# Nevada day 20
# 1027
# New Hampshire day 20
# 1028
# New Jersey day 20
# 1029
# New Mexico day 20
# 1030
# New York day 20
# 1031
# North Carolina day 20
# 1032
# North Dakota day 20
# 1033
# Ohio day 20
# 1034
# Oklahoma day 20
# 1035
# Oregon day 20
# 1036
# Pennsylvania day 20
# 1037
# Rhode Island day 20
# 1038
# South Carolina day 20
# 1039
# South Dakota day 20
# 1040
# Tennessee day 20
# 1041
# Texas day 20
# 1042
# Utah day 20
# 1043
# Vermont day 20
# 1044
# Virginia day 20
# 1045
# Washington day 20
# 1046
# West Virginia day 20
# 1047
# Wisconsin day 20
# 1048
# Wyoming day 20
# 1049
# Alabama day 21
# 1050
# Alaska day 21
# 1051
# Arizona day 21
# 1052
# Arkansas day 21
# 1053
# California day 21
# 1054
# Colorado day 21
# 1055
# Connecticut day 21
# 1056
# Delaware day 21
# 1057
# Florida day 21
# 1058
# Georgia day 21
# 1059
# Hawaii day 21
# 1060
# Idaho day 21
# 1061
# Illinois day 21
# 1062
# Indiana day 21
# 1063
# Iowa day 21
# 1064
# Kansas day 21
# 1065
# Kentucky day 21
# 1066
# Louisiana day 21
# 1067
# Maine day 21
# 1068
# Maryland day 21
# 1069
# Massachusetts day 21
# 1070
# Michigan day 21
# 1071
# Minnesota day 21
# 1072
# Mississippi day 21
# 1073
# Missouri day 21
# 1074
# Montana day 21
# 1075
# Nebraska day 21
# 1076
# Nevada day 21
# 1077
# New Hampshire day 21
# 1078
# New Jersey day 21
# 1079
# New Mexico day 21
# 1080
# New York day 21
# 1081
# North Carolina day 21
# 1082
# North Dakota day 21
# 1083
# Ohio day 21
# 1084
# Oklahoma day 21
# 1085
# Oregon day 21
# 1086
# Pennsylvania day 21
# 1087
# Rhode Island day 21
# 1088
# South Carolina day 21
# 1089
# South Dakota day 21
# 1090
# Tennessee day 21
# 1091
# Texas day 21
# 1092
# Utah day 21
# 1093
# Vermont day 21
# 1094
# Virginia day 21
# 1095
# Washington day 21
# 1096
# West Virginia day 21
# 1097
# Wisconsin day 21
# 1098
# Wyoming day 21
# 1099
# Alabama day 22
# 1100
# Alaska day 22
# 1101
# Arizona day 22
# 1102
# Arkansas day 22
# 1103
# California day 22
# 1104
# Colorado day 22
# 1105
# Connecticut day 22
# 1106
# Delaware day 22
# 1107
# Florida day 22
# 1108
# Georgia day 22
# 1109
# Hawaii day 22
# 1110
# Idaho day 22
# 1111
# Illinois day 22
# 1112
# Indiana day 22
# 1113
# Iowa day 22
# 1114
# Kansas day 22
# 1115
# Kentucky day 22
# 1116
# Louisiana day 22
# 1117
# Maine day 22
# 1118
# Maryland day 22
# 1119
# Massachusetts day 22
# 1120
# Michigan day 22
# 1121
# Minnesota day 22
# 1122
# Mississippi day 22
# 1123
# Missouri day 22
# 1124
# Montana day 22
# 1125
# Nebraska day 22
# 1126
# Nevada day 22
# 1127
# New Hampshire day 22
# 1128
# New Jersey day 22
# 1129
# New Mexico day 22
# 1130
# New York day 22
# 1131
# North Carolina day 22
# 1132
# North Dakota day 22
# 1133
# Ohio day 22
# 1134
# Oklahoma day 22
# 1135
# Oregon day 22
# 1136
# Pennsylvania day 22
# 1137
# Rhode Island day 22
# 1138
# South Carolina day 22
# 1139
# South Dakota day 22
# 1140
# Tennessee day 22
# 1141
# Texas day 22
# 1142
# Utah day 22
# 1143
# Vermont day 22
# 1144
# Virginia day 22
# 1145
# Washington day 22
# 1146
# West Virginia day 22
# 1147
# Wisconsin day 22
# 1148
# Wyoming day 22
# 1149
# Alabama day 23
# 1150
# Alaska day 23
# 1151
# Arizona day 23
# 1152
# Arkansas day 23
# 1153
# California day 23
# 1154
# Colorado day 23
# 1155
# Connecticut day 23
# 1156
# Delaware day 23
# 1157
# Florida day 23
# 1158
# Georgia day 23
# 1159
# Hawaii day 23
# 1160
# Idaho day 23
# 1161
# Illinois day 23
# 1162
# Indiana day 23
# 1163
# Iowa day 23
# 1164
# Kansas day 23
# 1165
# Kentucky day 23
# 1166
# Louisiana day 23
# 1167
# Maine day 23
# 1168
# Maryland day 23
# 1169
# Massachusetts day 23
# 1170
# Michigan day 23
# 1171
# Minnesota day 23
# 1172
# Mississippi day 23
# 1173
# Missouri day 23
# 1174
# Montana day 23
# 1175
# Nebraska day 23
# 1176
# Nevada day 23
# 1177
# New Hampshire day 23
# 1178
# New Jersey day 23
# 1179
# New Mexico day 23
# 1180
# New York day 23
# 1181
# North Carolina day 23
# 1182
# North Dakota day 23
# 1183
# Ohio day 23
# 1184
# Oklahoma day 23
# 1185
# Oregon day 23
# 1186
# Pennsylvania day 23
# 1187
# Rhode Island day 23
# 1188
# South Carolina day 23
# 1189
# South Dakota day 23
# 1190
# Tennessee day 23
# 1191
# Texas day 23
# 1192
# Utah day 23
# 1193
# Vermont day 23
# 1194
# Virginia day 23
# 1195
# Washington day 23
# 1196
# West Virginia day 23
# 1197
# Wisconsin day 23
# 1198
# Wyoming day 23
# 1199
# Alabama day 24
# 1200
# Alaska day 24
# 1201
# Arizona day 24
# 1202
# Arkansas day 24
# 1203
# California day 24
# 1204
# Colorado day 24
# 1205
# Connecticut day 24
# 1206
# Delaware day 24
# 1207
# Florida day 24
# 1208
# Georgia day 24
# 1209
# Hawaii day 24
# 1210
# Idaho day 24
# 1211
# Illinois day 24
# 1212
# Indiana day 24
# 1213
# Iowa day 24
# 1214
# Kansas day 24
# 1215
# Kentucky day 24
# 1216
# Louisiana day 24
# 1217
# Maine day 24
# 1218
# Maryland day 24
# 1219
# Massachusetts day 24
# 1220
# Michigan day 24
# 1221
# Minnesota day 24
# 1222
# Mississippi day 24
# 1223
# Missouri day 24
# 1224
# Montana day 24
# 1225
# Nebraska day 24
# 1226
# Nevada day 24
# 1227
# New Hampshire day 24
# 1228
# New Jersey day 24
# 1229
# New Mexico day 24
# 1230
# New York day 24
# 1231
# North Carolina day 24
# 1232
# North Dakota day 24
# 1233
# Ohio day 24
# 1234
# Oklahoma day 24
# 1235
# Oregon day 24
# 1236
# Pennsylvania day 24
# 1237
# Rhode Island day 24
# 1238
# South Carolina day 24
# 1239
# South Dakota day 24
# 1240
# Tennessee day 24
# 1241
# Texas day 24
# 1242
# Utah day 24
# 1243
# Vermont day 24
# 1244
# Virginia day 24
# 1245
# Washington day 24
# 1246
# West Virginia day 24
# 1247
# Wisconsin day 24
# 1248
# Wyoming day 24
# 1249
# Alabama day 25
# 1250
# Alaska day 25
# 1251
# Arizona day 25
# 1252
# Arkansas day 25
# 1253
# California day 25
# 1254
# Colorado day 25
# 1255
# Connecticut day 25
# 1256
# Delaware day 25
# 1257
# Florida day 25
# 1258
# Georgia day 25
# 1259
# Hawaii day 25
# 1260
# Idaho day 25
# 1261
# Illinois day 25
# 1262
# Indiana day 25
# 1263
# Iowa day 25
# 1264
# Kansas day 25
# 1265
# Kentucky day 25
# 1266
# Louisiana day 25
# 1267
# Maine day 25
# 1268
# Maryland day 25
# 1269
# Massachusetts day 25
# 1270
# Michigan day 25
# 1271
# Minnesota day 25
# 1272
# Mississippi day 25
# 1273
# Missouri day 25
# 1274
# Montana day 25
# 1275
# Nebraska day 25
# 1276
# Nevada day 25
# 1277
# New Hampshire day 25
# 1278
# New Jersey day 25
# 1279
# New Mexico day 25
# 1280
# New York day 25
# 1281
# North Carolina day 25
# 1282
# North Dakota day 25
# 1283
# Ohio day 25
# 1284
# Oklahoma day 25
# 1285
# Oregon day 25
# 1286
# Pennsylvania day 25
# 1287
# Rhode Island day 25
# 1288
# South Carolina day 25
# 1289
# South Dakota day 25
# 1290
# Tennessee day 25
# 1291
# Texas day 25
# 1292
# Utah day 25
# 1293
# Vermont day 25
# 1294
# Virginia day 25
# 1295
# Washington day 25
# 1296
# West Virginia day 25
# 1297
# Wisconsin day 25
# 1298
# Wyoming day 25
# 1299

# %%
trainrd2 = pd.read_csv("train_round2.csv")
datestofind = trainrd2['Date'] == '09-01-2020'
start = datestofind[datestofind == True].index[0]
datestofind2 = trainrd2['Date'] == '09-26-2020'
end = datestofind[datestofind2 == True].index[49]

validation = trainrd2.iloc[start:end+1,:]
validation
# Out:
#         ID Province_State        Date  Confirmed  Deaths  Recovered    Active  \
# 7100  7100        Alabama  09-01-2020     127616    2200    48028.0   77388.0
# 7101  7101         Alaska  09-01-2020       5297      39     2246.0    3012.0
# 7102  7102        Arizona  09-01-2020     202342    5044    30841.0  166457.0
# 7103  7103       Arkansas  09-01-2020      61497     814    55647.0    5036.0
# 7104  7104     California  09-01-2020     715617   13150        NaN  702467.0
# ...    ...            ...         ...        ...     ...        ...       ...
# 8395  8395       Virginia  09-26-2020     145267    3142    17255.0  124870.0
# 8396  8396     Washington  09-26-2020      85830    2100        NaN   83730.0
# 8397  8397  West Virginia  09-26-2020      15167     337    11121.0    3709.0
# 8398  8398      Wisconsin  09-26-2020     113645    1281    94094.0   18270.0
# 8399  8399        Wyoming  09-26-2020       5465      50     4479.0     936.0
#
#       Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 7100    2602.716398       958920.0                  NaN        1.723922
# 7101     724.083959       374255.0                  NaN        0.736266
# 7102    2779.912998      1208990.0                  NaN        2.492809
# 7103    2037.806299       731025.0                  NaN        1.323642
# 7104    1811.128167     11470696.0                  NaN        1.837575
# ...             ...            ...                  ...             ...
# 8395    1701.911741      1993344.0                  NaN        2.162914
# 8396    1127.133369      1801021.0                  NaN        2.446697
# 8397     846.303345       542291.0                  NaN        2.221929
# 8398    1951.846942      1513643.0                  NaN        1.127194
# 8399     944.261774        97871.0                  NaN        0.914913
#
#       Testing_Rate  Hospitalization_Rate
# 7100  19557.083814                   NaN
# 7101  51159.532223                   NaN
# 7102  16609.932767                   NaN
# 7103  24223.740177                   NaN
# 7104  29030.753344                   NaN
# ...            ...                   ...
# 8395  23353.518398                   NaN
# 8396  23651.297530                   NaN
# 8397  30259.292346                   NaN
# 8398  25996.739508                   NaN
# 8399  16910.492969                   NaN
#
# [1300 rows x 13 columns]

# %%
def MAPE(pred, valid):
    pred = pred.reset_index()
    valid = valid.reset_index()
    pred = pred.astype('int64')
    valid = valid.astype('int64')
    v = pred.subtract(valid)
    v = v.divide(valid)
    v = v.abs()
    v = v.sum(axis = 0)
    #v = v[0]+v[1]+v[2]
    n = len(pred)
    return v/n

# %%
test['Confirmed'] = conf
test['Deaths'] = dead
MAPE(test[['Confirmed', 'Deaths']], validation[['Confirmed', 'Deaths']])
# Out:
# index        0.918346
# Confirmed    0.019702
# Deaths       0.030000
# dtype: float64

# %%
validation.head()
# Out:
#         ID Province_State        Date  Confirmed  Deaths  Recovered    Active  \
# 7100  7100        Alabama  09-01-2020     127616    2200    48028.0   77388.0
# 7101  7101         Alaska  09-01-2020       5297      39     2246.0    3012.0
# 7102  7102        Arizona  09-01-2020     202342    5044    30841.0  166457.0
# 7103  7103       Arkansas  09-01-2020      61497     814    55647.0    5036.0
# 7104  7104     California  09-01-2020     715617   13150        NaN  702467.0
#
#       Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 7100    2602.716398       958920.0                  NaN        1.723922
# 7101     724.083959       374255.0                  NaN        0.736266
# 7102    2779.912998      1208990.0                  NaN        2.492809
# 7103    2037.806299       731025.0                  NaN        1.323642
# 7104    1811.128167     11470696.0                  NaN        1.837575
#
#       Testing_Rate  Hospitalization_Rate
# 7100  19557.083814                   NaN
# 7101  51159.532223                   NaN
# 7102  16609.932767                   NaN
# 7103  24223.740177                   NaN
# 7104  29030.753344                   NaN

# %%
def difference(dataset, interval = 1):
    diff = list()
    for i in range(interval, len(dataset)):
        value = dataset[i]-dataset[i-interval]
        diff.append(value)
    return np.array(diff)

# invert differenced value
def inverse_difference(history, yhat, interval=1):
    #yhat = np.exp(yhat)
    return yhat + history[-1]


a= [2,3,7,9]
diff0 = difference(a,1)
diff = difference(diff0, 1)

# %%
test
# Out:
#       ForecastID Province_State        Date  Confirmed  Deaths
# 0              0        Alabama  09-01-2020     127516    2194
# 1              1         Alaska  09-01-2020       5315      37
# 2              2        Arizona  09-01-2020     202326    5065
# 3              3       Arkansas  09-01-2020      61703     812
# 4              4     California  09-01-2020     718134   13142
# ...          ...            ...         ...        ...     ...
# 1295        1295       Virginia  09-26-2020     146220    2910
# 1296        1296     Washington  09-26-2020      87403    2101
# 1297        1297  West Virginia  09-26-2020      14167     313
# 1298        1298      Wisconsin  09-26-2020      92762    1270
# 1299        1299        Wyoming  09-26-2020       4730      43
#
# [1300 rows x 5 columns]

# %%
inverse_difference(a, diff0[0], 1)
# Out:
# 10

# %%
submission = test.drop(columns=['Province_State', 'Date'])
submission
# Out:
#       ForecastID  Confirmed  Deaths
# 0              0     127516    2194
# 1              1       5315      37
# 2              2     202326    5065
# 3              3      61703     812
# 4              4     718134   13142
# ...          ...        ...     ...
# 1295        1295     146220    2910
# 1296        1296      87403    2101
# 1297        1297      14167     313
# 1298        1298      92762    1270
# 1299        1299       4730      43
#
# [1300 rows x 3 columns]

# %%
#submission.to_csv('team31-dec3-1.csv', index = False, header = True)

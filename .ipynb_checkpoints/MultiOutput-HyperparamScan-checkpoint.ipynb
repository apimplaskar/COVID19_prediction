# %%
# Packages
import numpy as np
import sklearn 
import pandas as pd
import matplotlib.pyplot as plt
import scipy
from scipy.integrate import odeint
from scipy.optimize import minimize
from utility_code.utility import utils

# %%
trainrd2 = pd.read_csv("train_round2.csv")
datestofind = trainrd2['Date'] == '09-01-2020'
start = datestofind[datestofind == True].index[0]
datestofind2 = trainrd2['Date'] == '09-26-2020'
end = datestofind[datestofind == True].index[49]

bestsub = pd.read_csv("team31-nov29-2.csv")

validation = trainrd2.iloc[start:end,:]
def MAPE(pred, valid):
    pred = pred.reset_index()
    valid = valid.reset_index()
    pred = pred.astype('int64')
    valid = valid.astype('int64')
    v = pred.subtract(valid)
    v = v.divide(valid)
    v = v.abs()
    v = v.sum(axis = 0)
    #v = v[0]+v[1]+v[2]
    n = len(pred)
    return v/n

# %%
#import csvs
train = pd.read_csv("ucla2020-cs145-covid19-prediction/train.csv")
test = pd.read_csv("ucla2020-cs145-covid19-prediction/test.csv")
graph = pd.read_csv("ucla2020-cs145-covid19-prediction/graph.csv")
supp = pd.read_csv("data-test/raw_data_test.csv", skiprows=2, thousands=',')
supp = supp[supp['Location'].isin(train['Province_State'])]
supp['Population'] = supp['Number of COVID-19 Cases'].divide(supp['COVID-19 Cases per 1,000,000 Population']) * 1e6

states = pd.Series.unique(train['Province_State'])
num_states = len(states)

# %%
## MANIPULATES MODEL AND MODEL PARAMS
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge
import random

###################################################
#TRY DIFFERENT VALUES FOR PARAMETERS AND KEEP THE BEST
best_parameter_setup = { 'alpha': 100,
                         'max_iter': 5000,
                         'tol': 0.005,
                         'random_state':229018,
                         'window_size':5,
                         'confirmed_error': 7.667212448385207e-05,
                         'deaths_error': 0.00016738204091735175  }

best_parameter_setups = [best_parameter_setup]
confirmed_error_best = 1 
deaths_error_best = 1

#returns sample taken from normal distribution, bounds the sample with min and max
DEFAULT_MIN = 1e-25
DEFAULT_MAX = 999999
def normal_sample (mean,sd,mn,mx,rnd = False):
    sample = max(mn, min(mx, np.random.normal(mean, sd)))
    if rnd:
        return int(sample)
    else:
        return sample


ITERATIONS = 100
parameter_setup = {}

print("Starting using previous best setup...")

for it in range(ITERATIONS+1):
    
    #standard deviations: try increasing sd_scale for more variance (or decreasing for opposite effect)
    sd_scale = 50 / len(best_parameter_setups) #sd goes down as more solutions are found
    alpha_sd = 0.2 * sd_scale;
    max_iter_sd = 100 * sd_scale;
    tol_sd = 5e-4 * sd_scale;
    
    
    #apply normal "randomization"
    parameter_setup = {}
    if it > 0:
        parameter_setup['alpha'] = normal_sample( best_parameter_setups[-1]['alpha'], alpha_sd, DEFAULT_MIN, DEFAULT_MAX)
        parameter_setup['max_iter'] = normal_sample( best_parameter_setups[-1]['max_iter'], max_iter_sd, 1, DEFAULT_MAX, rnd=True)
        parameter_setup['tol'] = normal_sample( best_parameter_setups[-1]['tol'], tol_sd, DEFAULT_MIN, 20) 
        parameter_setup['random_state'] = random.randint(0,DEFAULT_MAX)
        parameter_setup['window_size'] = random.randint(1,14)
    else:
        parameter_setup = best_parameter_setups[-1]
    
    
    #choose a regressor
    reg = MultiOutputRegressor(estimator=Ridge(
                                    alpha=parameter_setup['alpha'],
                                    max_iter=parameter_setup['max_iter'],
                                    tol=parameter_setup['tol'],
                                    random_state = parameter_setup['random_state']))
        
###################################################

    ## MANIPULATES FEATURES FROM DF TO USE AND WINDOW SIZE
    #only look at the features in features list
    features = ['Confirmed','Deaths']
    num_features = len(features)

    #stratify by state (into state dictionary)
    statesdata = {}
    for s in states:
        statesdata[s] = train.loc[train['Province_State'] == s,features]

    
    ###################################################
    WINDOW_SIZE = parameter_setup['window_size']
    ###################################################
    
    state_feature_indices = utils.get_column_indices(statesdata['California'],features)

    #append the feature spaces from the W days prior (where W is the window length)
    new_features = []
    for day in range(WINDOW_SIZE):
        for f in features:
            new_features.append(f + "(-"+ str(WINDOW_SIZE-day) + " days)")
    all_new_features = new_features + features

    ## Set up dictionary of projections
    proj = {}

    ## Loop over states
    for s in states:

        a = statesdata[s]

        #fill the knn data using days from training set
        knndata = pd.DataFrame(columns = all_new_features)
        num_training_days = len(statesdata['California'])

        #fill the table
        for d in range(WINDOW_SIZE,num_training_days):
            knndata_row_index = knndata.shape[0]
            knn_row = utils.flatten_dataframe(a,slice(d-WINDOW_SIZE,d+1), state_feature_indices)
            utils.dataframe_append_row(knndata,knn_row,s,d)   

        # Actual recursive prediction
        days_to_predict = 26
        for d in range(days_to_predict):
            #x = knndata.drop(columns=features)
            #y = knndata.drop(columns=features)
            x = knndata.drop(['Confirmed', 'Deaths'], axis = 1)
            y = knndata[['Confirmed', 'Deaths']]
            toguess = 1
            trainx = x.head(len(x))
            trainy = y.head(len(y))
            # testy = y.tail(toguess)

            reg.fit(trainx, trainy)

            #rmv = [i for i in range(num_features)]
            #ftrs = knndata.drop(columns=knndata.columns[rmv]).tail(1)
            ftrs = knndata.drop(columns=knndata.columns[[0,1]]).tail(1)
            #ftrs.drop(columns=knndata.columns[[0,1]])

            ftrs.columns = knndata.columns[0:num_features*WINDOW_SIZE]

            new = reg.predict(ftrs)
            ftrs = np.append(ftrs, new)
            ftrs = ftrs.astype(int)
            #if d==0: print(ftrs)
            knndata = knndata.append(dict(zip(knndata.columns, ftrs)), ignore_index=True)

            # append to knndata
            #if d == 0: 
                #print(knndata)
        done = knndata.tail(days_to_predict)
        done = done[['Confirmed', 'Deaths']]
        #print(done)
        proj[s] = done

    ## Get ordering of states in test    
    order = test.loc[0:49,'Province_State']

    # format submission
    conf = []
    dead = []
    fid = 0
    for i in range(days_to_predict):
        for j in order:
            projection = proj[j].iloc[i]
            #print(j, 'day', i)
            conf.append(int(projection['Confirmed']))
            dead.append(int(projection['Deaths']))
            #print(fid)
            fid+=1

    test['Confirmed'] = conf
    test['Deaths'] = dead

###################################################
    errors = MAPE(test[['Confirmed', 'Deaths']], validation[['Confirmed', 'Deaths']])
    parameter_setup['confirmed_error'] = errors['Confirmed']
    parameter_setup['deaths_error'] = errors['Deaths']
    
    
    found_good_sol = False
    if(parameter_setup['confirmed_error'] < confirmed_error_best):
        confirmed_error_best = parameter_setup['confirmed_error']
        found_good_sol = True
    if(parameter_setup['deaths_error'] < deaths_error_best):
        deaths_error_best = parameter_setup['deaths_error']
        found_good_sol = True
    if found_good_sol:
        best_parameter_setups.append(parameter_setup)
        
    if found_good_sol:
        if it == 0:
            print("(*) SETUP:","Confirmed Error: "+str(parameter_setup['confirmed_error'])," | Deaths Error: "+str(parameter_setup['deaths_error']))
        else:
            print("(*) ITERATION "+str(it)+":","Confirmed Error: "+str(parameter_setup['confirmed_error'])," | Deaths Error: "+str(parameter_setup['deaths_error']))
    else:
        if it == 0:
            print("(-) SETUP:","Confirmed Error: "+str(parameter_setup['confirmed_error'])," | Deaths Error: "+str(parameter_setup['deaths_error']))
        else:
            print("(-) ITERATION "+str(it)+":","Confirmed Error: "+str(parameter_setup['confirmed_error'])," | Deaths Error: "+str(parameter_setup['deaths_error']))
        
        
print("Found",len(best_parameter_setups) - 1,"good solutions!")
###################################################
# Out:
# Starting using previous best setup...
# (*) SETUP: Confirmed Error: 7.667212448385207e-05  | Deaths Error: 0.00016738204091735175
# (-) ITERATION 1: Confirmed Error: 8.35182664378339e-05  | Deaths Error: 0.000186474359543878
# (-) ITERATION 2: Confirmed Error: 8.35182664378339e-05  | Deaths Error: 0.000186474359543878
# (-) ITERATION 3: Confirmed Error: 9.064396156895488e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 4: Confirmed Error: 8.743342342353557e-05  | Deaths Error: 0.000189441955911648
# (-) ITERATION 5: Confirmed Error: 8.757810223111963e-05  | Deaths Error: 0.00017904694551663762
# (-) ITERATION 6: Confirmed Error: 8.630727811173464e-05  | Deaths Error: 0.0001974504923932348
# (-) ITERATION 7: Confirmed Error: 8.613113137817504e-05  | Deaths Error: 0.00018418789292373876
# (-) ITERATION 8: Confirmed Error: 8.280196772591517e-05  | Deaths Error: 0.00017968191404611904
# (-) ITERATION 9: Confirmed Error: 8.603762174373727e-05  | Deaths Error: 0.00019716985365947676
# (-) ITERATION 10: Confirmed Error: 9.072148626654263e-05  | Deaths Error: 0.00017474199701159442
# (*) ITERATION 11: Confirmed Error: 7.662777875108111e-05  | Deaths Error: 0.00017777705131236213
# (-) ITERATION 12: Confirmed Error: 9.845801418233723e-05  | Deaths Error: 0.00020904793368894118
# (-) ITERATION 13: Confirmed Error: 8.266506272075223e-05  | Deaths Error: 0.00018706021694618624
# (-) ITERATION 14: Confirmed Error: 9.252316476759553e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 15: Confirmed Error: 0.000137874962575122  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 16: Confirmed Error: 8.368022785367539e-05  | Deaths Error: 0.00017968191404611904
# (-) ITERATION 17: Confirmed Error: 8.25761651396554e-05  | Deaths Error: 0.00018706021694618624
# (-) ITERATION 18: Confirmed Error: 8.220371117259958e-05  | Deaths Error: 0.0001974552273411966
# (-) ITERATION 19: Confirmed Error: 9.248148367644794e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 20: Confirmed Error: 8.770431958482274e-05  | Deaths Error: 0.00017904694551663762
# (-) ITERATION 21: Confirmed Error: 9.041451562234566e-05  | Deaths Error: 0.00018206800433760172
# (-) ITERATION 22: Confirmed Error: 9.11108529050418e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 23: Confirmed Error: 8.313332680678312e-05  | Deaths Error: 0.000186474359543878
# (-) ITERATION 24: Confirmed Error: 0.00013793091070002058  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 25: Confirmed Error: 8.616865878764208e-05  | Deaths Error: 0.00017728465340176555
# (-) ITERATION 26: Confirmed Error: 8.738016087670847e-05  | Deaths Error: 0.00018938345927520462
# (-) ITERATION 27: Confirmed Error: 8.382544793470818e-05  | Deaths Error: 0.00017968191404611904
# (-) ITERATION 28: Confirmed Error: 8.602116633751949e-05  | Deaths Error: 0.00019716985365947676
# (-) ITERATION 29: Confirmed Error: 7.671667633217793e-05  | Deaths Error: 0.00016738204091735175
# (-) ITERATION 30: Confirmed Error: 8.628767838655792e-05  | Deaths Error: 0.0001974504923932348
# (-) ITERATION 31: Confirmed Error: 7.945848065868349e-05  | Deaths Error: 0.00018868431604772995
# (-) ITERATION 32: Confirmed Error: 9.166857290514406e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 33: Confirmed Error: 9.780263071071531e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 34: Confirmed Error: 8.628502928980976e-05  | Deaths Error: 0.00019716985365947676
# (-) ITERATION 35: Confirmed Error: 9.279654761686406e-05  | Deaths Error: 0.00020158934743692424
# (-) ITERATION 36: Confirmed Error: 7.945848065868349e-05  | Deaths Error: 0.00018868431604772995
# (-) ITERATION 37: Confirmed Error: 0.000137874962575122  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 38: Confirmed Error: 8.94373049287069e-05  | Deaths Error: 0.000180051575359537
# (-) ITERATION 39: Confirmed Error: 8.725394352300536e-05  | Deaths Error: 0.00018938345927520462
# (-) ITERATION 40: Confirmed Error: 9.046176983960996e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 41: Confirmed Error: 8.952295441010242e-05  | Deaths Error: 0.000180051575359537
# (-) ITERATION 42: Confirmed Error: 0.000137874962575122  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 43: Confirmed Error: 9.280905604441713e-05  | Deaths Error: 0.00020158934743692424
# (-) ITERATION 44: Confirmed Error: 7.931687756433855e-05  | Deaths Error: 0.00018868431604772995
# (*) ITERATION 45: Confirmed Error: 7.658322690275525e-05  | Deaths Error: 0.00016738204091735175
# (-) ITERATION 46: Confirmed Error: 9.073285915005172e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 47: Confirmed Error: 9.08053145319182e-05  | Deaths Error: 0.00017608247944705054
# (-) ITERATION 48: Confirmed Error: 8.25761651396554e-05  | Deaths Error: 0.00018706021694618624
# (-) ITERATION 49: Confirmed Error: 9.100088296334989e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 50: Confirmed Error: 9.128299743429795e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 51: Confirmed Error: 0.000137874962575122  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 52: Confirmed Error: 9.113361624199603e-05  | Deaths Error: 0.00017608247944705054
# (-) ITERATION 53: Confirmed Error: 9.058283936505856e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 54: Confirmed Error: 9.028466040761499e-05  | Deaths Error: 0.00018432320292533194
# (-) ITERATION 55: Confirmed Error: 8.305909939624634e-05  | Deaths Error: 0.000186474359543878
# (-) ITERATION 56: Confirmed Error: 8.305909939624634e-05  | Deaths Error: 0.000186474359543878
# (-) ITERATION 57: Confirmed Error: 7.662777875108111e-05  | Deaths Error: 0.00017777705131236213
# (-) ITERATION 58: Confirmed Error: 9.07193155579922e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 59: Confirmed Error: 0.000137874962575122  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 60: Confirmed Error: 9.113361624199603e-05  | Deaths Error: 0.00017608247944705054
# (-) ITERATION 61: Confirmed Error: 8.949098367032029e-05  | Deaths Error: 0.000180051575359537
# (-) ITERATION 62: Confirmed Error: 8.266259608757546e-05  | Deaths Error: 0.00016928690365110869
# (-) ITERATION 63: Confirmed Error: 8.946720748977347e-05  | Deaths Error: 0.000180051575359537
# (-) ITERATION 64: Confirmed Error: 8.304940429191484e-05  | Deaths Error: 0.00017968191404611904
# (-) ITERATION 65: Confirmed Error: 8.966325390206198e-05  | Deaths Error: 0.000180051575359537
# (-) ITERATION 66: Confirmed Error: 8.35182664378339e-05  | Deaths Error: 0.000186474359543878
# (*) ITERATION 67: Confirmed Error: 8.561180227744546e-05  | Deaths Error: 0.00016620588232299445
# (-) ITERATION 68: Confirmed Error: 0.00013793091070002058  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 69: Confirmed Error: 9.028466040761499e-05  | Deaths Error: 0.00018432320292533194
# (-) ITERATION 70: Confirmed Error: 7.677570120105238e-05  | Deaths Error: 0.00018710590679506375
# (-) ITERATION 71: Confirmed Error: 9.780263071071531e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 72: Confirmed Error: 7.677570120105238e-05  | Deaths Error: 0.00018710590679506375
# (-) ITERATION 73: Confirmed Error: 8.009859641178407e-05  | Deaths Error: 0.0001782893056527195
# (-) ITERATION 74: Confirmed Error: 8.020322209150544e-05  | Deaths Error: 0.0001782893056527195
# (-) ITERATION 75: Confirmed Error: 9.093689673113776e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 76: Confirmed Error: 9.128299743429795e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 77: Confirmed Error: 9.072148626654263e-05  | Deaths Error: 0.00017474199701159442
# (-) ITERATION 78: Confirmed Error: 8.562431070499852e-05  | Deaths Error: 0.00016620588232299445
# (-) ITERATION 79: Confirmed Error: 8.927435122492295e-05  | Deaths Error: 0.00016965656496452662
# (-) ITERATION 80: Confirmed Error: 9.162999953369308e-05  | Deaths Error: 0.00017420171962008045
# (-) ITERATION 81: Confirmed Error: 9.823928369132716e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 82: Confirmed Error: 8.726943421697261e-05  | Deaths Error: 0.00017829555420431788
# (-) ITERATION 83: Confirmed Error: 0.00013793091070002058  | Deaths Error: 0.00019754960504497402
# (-) ITERATION 84: Confirmed Error: 9.823928369132716e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 85: Confirmed Error: 8.881968825449485e-05  | Deaths Error: 0.00016965656496452662
# (-) ITERATION 86: Confirmed Error: 8.630727811173464e-05  | Deaths Error: 0.0001974504923932348
# (-) ITERATION 87: Confirmed Error: 9.091198538225307e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 88: Confirmed Error: 8.745743320588189e-05  | Deaths Error: 0.00017829555420431788
# (-) ITERATION 89: Confirmed Error: 9.138337344401038e-05  | Deaths Error: 0.00017420171962008045
# (-) ITERATION 90: Confirmed Error: 9.794785079174812e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 91: Confirmed Error: 9.086920647437658e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 92: Confirmed Error: 8.613113137817504e-05  | Deaths Error: 0.00018418789292373876
# (-) ITERATION 93: Confirmed Error: 9.11759743055918e-05  | Deaths Error: 0.00018461770168843713
# (-) ITERATION 94: Confirmed Error: 8.912913114389015e-05  | Deaths Error: 0.00016965656496452662
# (-) ITERATION 95: Confirmed Error: 8.613113137817504e-05  | Deaths Error: 0.00018418789292373876
# (-) ITERATION 96: Confirmed Error: 9.138337344401038e-05  | Deaths Error: 0.00017420171962008045
# (-) ITERATION 97: Confirmed Error: 9.760245524229736e-05  | Deaths Error: 0.0002007489199403362
# (-) ITERATION 98: Confirmed Error: 9.188060257115295e-05  | Deaths Error: 0.00019119433704191385
# (-) ITERATION 99: Confirmed Error: 9.162999953369308e-05  | Deaths Error: 0.00017420171962008045
# (-) ITERATION 100: Confirmed Error: 8.279028563304487e-05  | Deaths Error: 0.00017968191404611904
# Found 4 good solutions!

# %%
for setup in best_parameter_setups[1:]:
        print(setup)
        print()
# Out:
# {'alpha': 1.6625501873415338, 'max_iter': 5000, 'tol': 0.005, 'random_state': 229018, 'window_size': 5, 'confirmed_error': 7.667212448385207e-05, 'deaths_error': 0.00016738204091735175}
#
# {'alpha': 6.901907484961538, 'max_iter': 2973, 'tol': 0.005181094039896343, 'random_state': 940112, 'window_size': 5, 'confirmed_error': 7.662777875108111e-05, 'deaths_error': 0.00017777705131236213}
#
# {'alpha': 2.934711595714482, 'max_iter': 2612, 'tol': 0.022691053827015945, 'random_state': 595350, 'window_size': 5, 'confirmed_error': 7.658322690275525e-05, 'deaths_error': 0.00016738204091735175}
#
# {'alpha': 0.286109713976066, 'max_iter': 3693, 'tol': 0.014557779654411728, 'random_state': 362340, 'window_size': 9, 'confirmed_error': 8.561180227744546e-05, 'deaths_error': 0.00016620588232299445}

# %%
best_parameter_setups[3]

# %%
#submission = test.drop(columns=['Date', 'Province_State'])
print(submission)
filename = "team31-dec1-1-nosub.csv"
#submission.to_csv(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5b6802285835> in <module>
#       1 #submission = test.drop(columns=['Date', 'Province_State'])
# ----> 2 print(submission)
#       3 filename = "team31-dec1-1-nosub.csv"
#       4 #submission.to_csv(filename)
#
# NameError: name 'submission' is not defined

# %%
print(MAPE(bestsub[['Confirmed', 'Deaths']], validation[['Confirmed', 'Deaths']]))
print("Error of current run")
print(MAPE(test[['Confirmed', 'Deaths']], validation[['Confirmed', 'Deaths']]))

# %%
submission['Confirmed']=bestsub['Confirmed']
submission['Deaths']=test['Deaths']

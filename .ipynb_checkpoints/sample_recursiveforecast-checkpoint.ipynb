# %%
import numpy as np
import pandas as pd
import sklearn

# %%
# toy data
days = 60
data = np.random.randn(days, 10)
data = np.transpose(data)
data = pd.DataFrame(data)
data
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.715502  0.199866 -1.192530  0.566596 -0.120936  0.609272 -0.752866
# 1 -0.063257 -0.007421  1.535106  0.110123  0.197059  2.078528 -1.021609
# 2  0.441925 -0.138369  0.023104 -1.365090  1.963309 -0.075141  3.125446
# 3  0.904247 -1.413055  1.995867  0.685442 -0.272374  1.092626 -0.934200
# 4  1.053398  0.035577  0.176339 -0.700703  2.381574  0.356625 -0.803764
# 5 -1.038165 -0.147715 -0.356982  1.264963  0.846848 -0.538774  0.496324
# 6 -0.889605 -1.682040 -0.216245 -0.138387  0.619662 -0.878477  0.496166
# 7  0.170978 -0.025526 -0.489421  1.157259  0.691283  0.023784 -0.072861
# 8 -0.041179  0.580537  1.223959  0.686596 -0.386484  1.659917 -0.456742
# 9  0.212549 -0.751699  0.173963 -0.310565 -0.542342  1.044845 -1.346611
#
#          7         8         9   ...        50        51        52        53  \
# 0 -0.868714  1.030484 -0.206578  ... -0.542394  0.277238 -0.495552  1.093961
# ...

# %% [markdown]
# ## Algorithm: Based on direct-recursive hybrid forecasting
# IDEA:
#
#     prediction(t+1) = model1(obs(t),obs(t-1), obs(t-2), ... obs(t-n))
#
#     prediction(t+2) = model2(prediction(t+1), obs(t), ..., obs(t-n))
# ...
#
#
#
#     forecast = function(data, days_to_forecast, window){
#
#         t = last day of given data
#
#         for i = 1:days_to_forecast{
#
#             model = train(y ~ x[t-n, t-1])
#
#             prediction = computePrediction(x[t])
#
#             x = concatenate(x, prediction)
#
#             t+=1
#         }
#     }
